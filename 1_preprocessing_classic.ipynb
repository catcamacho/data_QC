# %% [markdown]
# # Infant resting state fMRI preprocessing
# This notebook contains preprocessing tailored to infant resting state fMRI collected in 5-8 month olds.
#
# The processing steps for the fMRI broadly include:
# * Slice-time correction
# * Rigid realignment
# * Co-registration to the sMRI (T2-weighted structural MRI)
# * Artifact detection:
#     - Motion
#     - Global intensity outliers
# * De-noising to remove:
#     - Component noise associated with white matter and CSF
#     - component noise associated with motion
#     - Censoring/scrubbing of individual volumes detected as artifacts in the previous step
#     - Frame-wise displacement
# * Bandpass filtering
# * Spatial smoothing
# * Registration to infant sample template

# %%
#import packages
from os import listdir, makedirs
from os.path import isdir
from nipype.interfaces.io import DataSink, SelectFiles, DataGrabber # Data i/o
from nipype.interfaces.utility import IdentityInterface, Function     # utility
from nipype.pipeline.engine import Node, Workflow, MapNode        # pypeline engine
from nipype.interfaces.nipy.preprocess import Trim

from nipype.algorithms.rapidart import ArtifactDetect
from nipype.interfaces.fsl import SliceTimer, MCFLIRT, FLIRT, FAST, SUSAN, ApplyTOPUP, TOPUP
from nipype.interfaces.fsl import Reorient2Std, MotionOutliers, Merge, ExtractROI, GLM, MELODIC, ApplyMask, TemporalFilter
from nipype.interfaces.freesurfer import Resample, Binarize, MRIConvert
from nipype.algorithms.confounds import CompCor
from nipype.algorithms.misc import Gunzip
from nipype.interfaces.afni import Bandpass, AFNItoNIFTI
from pandas import DataFrame, Series

#set output file type for FSL to NIFTI
from nipype.interfaces.fsl.preprocess import FSLCommand
FSLCommand.set_default_output_type('NIFTI_GZ')

# MATLAB setup - Specify path to current SPM and the MATLAB's default mode
from nipype.interfaces.matlab import MatlabCommand
MatlabCommand.set_default_paths('~/spm12')
MatlabCommand.set_default_matlab_cmd("matlab -nodesktop -nosplash")

# Set study variables
setup='Cat'
sample='newborn' #6mo or newborn
sequence='mux6'#spiral or mux6

if setup=='Marissa':
    studyhome = '/Volumes/iang/BABIES_data/BABIES_rest'
    raw_data = studyhome + '/subjDir/all/'
    output_dir = studyhome + '/processed/preproc'
    workflow_dir = studyhome + '/workflows' 
    templates = '/Volumes/iang/BABIES_data/BABIES_rest/templates'
elif setup=='Cat':
    studyhome = '/home/camachocm2/Analysis/SEA/rest_proc'
    raw_data = studyhome + '/raw'
    output_dir = studyhome + '/preproc'
    workflow_dir = studyhome + '/workflows'
    templates = '/home/camachocm2/Analysis/SEA/templates'

if sample =='6mo':
    template_brain = templates + '/6mo_T2w_template_2mm.nii.gz'
    template_wm = templates + '/6mo_T2w_template_2mm_wm.nii.gz'
    template_mask = templates + '/6mo_T2w_template_2mm_mask.nii.gz'
elif sample=='newborn':
    template_brain = templates + '/neonate_T2w_template_2mm.nii.gz'
    template_wm = templates + '/neonate_T2w_template_2mm_wm.nii.gz'
    template_mask = templates + '/neonate_T2w_template_2mm_gm.nii.gz'

if sequence=='spiral':
    vols_to_trim = 4
    interleave = False
    TR = 2.5 # in seconds
elif sequence=='mux6':
    custom_timings = studyhome + '/misc/slice_timing.txt'
    vols_to_trim = 6
    TR = 1.41 # in seconds

#subjects_list = open(studyhome + '/misc/all_subjects.txt').read().splitlines()
subjects_list = ['N1011']

proc_cores = 4# number of cores of processing for the workflows
resampled_voxel_size = (2,2,2)
fwhm = 4 #fwhm for smoothing with SUSAN
slice_dir = 3 # 1=x, 2=y, 3=z
phase_encoding_file = studyhome + '/misc/SEA_rest_encoding.txt'

#changed to match Pendl et al 2017 (HBM)
highpass_freq = 0.005 #in Hz
lowpass_freq = 0.1 #in Hz

mask_erosion = 1
mask_dilation = 1

# %%
## File handling Nodes

# Identity node- select subjects
infosource = Node(IdentityInterface(fields=['subject_id']),
                     name='infosource')
infosource.iterables = ('subject_id', subjects_list)

# Datasink- where our select outputs will go
substitutions = [('_subject_id_', '')]
datasink = Node(DataSink(), name='datasink')
datasink.inputs.base_directory = output_dir
datasink.inputs.container = output_dir
datasink.inputs.substitutions = substitutions

# Data grabber- select fMRI and sMRI
anat_template = {'struct': raw_data + '/{subject_id}/skullstripped_anat.nii.gz'}
select_anat = Node(SelectFiles(anat_template), name='selectanat')

# %% [markdown]
# ### Unwarping workflow

# %%
def sort_pes(pes):
    from nipype import config, logging
    from nipype.interfaces.fsl import Merge
    from os.path import abspath
    config.enable_debug_mode()
    logging.update_logging(config)
    
    print(pes)
    pe1s = []
    pe0s = []
    for file in pes:
        if 'FSP' in file:
            pe0s.append(file)
        elif 'FSA' in file:
            pe1s.append(file)
    
    if len(pe1s) < len(pe0s):
        for a in range(len(pe1s),len(pe0s)):
            pe1s.append(pe1s[0])
    
    pe1s = sorted(pe1s)
    pe0s = sorted(pe0s)

    me = Merge()
    merged_pes = []
    
    for i in range(0,len(pe1s)):
        num=pe1s[i][-12:-11]
        me.inputs.in_files = [pe1s[i],pe0s[i]]
        me.inputs.dimension='t'
        me.inputs.merged_file = 'merged_pes%s.nii.gz' % num
        me.run()
        file = abspath('merged_pes%s.nii.gz' % num)
        merged_pes.append(file)
        
    return(merged_pes)

# %%
if sequence=='mux6':
    pes_template = {'pes': raw_data + '/%s/*rsEPI-FS*.nii.gz'}
    select_pes = Node(DataGrabber(sort_filelist=True,
                                  template = raw_data + '/%s/*rsEPI-FS*.nii.gz',
                                  field_template = pes_template,
                                  base_directory=raw_data,
                                  infields=['subject_id'], 
                                  template_args={'pes':[['subject_id']]}), 
                      name='select_pes')

    func_template = {'func': raw_data + '/%s/*rsEPI-FSP*.nii.gz'}
    select_func = Node(DataGrabber(sort_filelist=True,
                                   template = raw_data + '/%s/*rsEPI-FSP*.nii.gz',
                                   field_template = func_template,
                                   base_directory=raw_data,
                                   infields=['subject_id'], 
                                   template_args={'func':[['subject_id']]}), 
                       name='select_func')

    # include only the first volume of each PE volume
    trim_PEs = MapNode(ExtractROI(t_min=0, t_size=5),name='trim_PEs', 
                       iterfield=['in_file'])

    sort_pe_list = Node(Function(input_names=['pes'],
                                 output_names=['merged_pes'],
                                 function=sort_pes), 
                        name='sort_pe_list')

    topup = MapNode(TOPUP(encoding_file=phase_encoding_file), name='topup',iterfield=['in_file'])

    apply_topup = MapNode(ApplyTOPUP(in_index=[2], encoding_file=phase_encoding_file,
                                     method='jac', out_corrected='func_unwarped.nii.gz'),
                          name='apply_topup',iterfield=['in_topup_fieldcoef','in_topup_movpar','in_files'])

# %%
if sequence=='mux6':
    prepreprocflow = Workflow(name='prepreprocflow')
    prepreprocflow.connect([(infosource,select_pes, [('subject_id','subject_id')]),
                            (infosource,select_func, [('subject_id','subject_id')]),
                            (select_pes,trim_PEs, [('pes','in_file')]), 
                            (trim_PEs,sort_pe_list, [('roi_file','pes')]),
                            (sort_pe_list,topup, [('merged_pes','in_file')]),
                            (topup, apply_topup, [('out_fieldcoef','in_topup_fieldcoef'), 
                                                  ('out_movpar','in_topup_movpar')]),
                            (select_func, apply_topup, [('func','in_files')]),
                            (apply_topup, datasink, [('out_corrected','unwarped_funcs')])
                           ])

    prepreprocflow.base_dir = workflow_dir
    prepreprocflow.write_graph(graph2use='flat')
    prepreprocflow.run('MultiProc', plugin_args={'n_procs': proc_cores, 'memory_gb':20})
# Out:
# 190406-13:53:35,192 workflow INFO:
# 	 Generated workflow graph: /home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/graph.png (graph2use=flat, simple_form=True).
# 190406-13:53:35,228 workflow INFO:
# 	 Workflow prepreprocflow settings: ['check', 'execution', 'logging', 'monitoring']
# 190406-13:53:35,250 workflow INFO:
# 	 Running in parallel.
# 190406-13:53:35,254 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 20.00/20.00, Free processors: 4/4.
# 190406-13:53:35,362 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.select_func" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/select_func".190406-13:53:35,364 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.select_pes" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/select_pes".
#
# 190406-13:53:35,375 workflow INFO:
# 	 [Node] Running "select_func" ("nipype.interfaces.io.DataGrabber")190406-13:53:35,376 workflow INFO:
# 	 [Node] Running "select_pes" ("nipype.interfaces.io.DataGrabber")
#
# 190406-13:53:35,384 workflow INFO:
# 	 [Node] Finished "prepreprocflow.select_func".
# 190406-13:53:35,389 workflow INFO:
# 	 [Node] Finished "prepreprocflow.select_pes".
# 190406-13:53:37,256 workflow INFO:
# 	 [Job 0] Completed (prepreprocflow.select_func).
# 190406-13:53:37,261 workflow INFO:
# 	 [Job 1] Completed (prepreprocflow.select_pes).
# 190406-13:53:37,265 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 20.00/20.00, Free processors: 4/4.
# 190406-13:53:39,259 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 20.00/20.00, Free processors: 4/4.
# 190406-13:53:39,356 workflow INFO:
# 	 [Node] Setting-up "_trim_PEs2" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/trim_PEs/mapflow/_trim_PEs2".
# 190406-13:53:39,357 workflow INFO:
# 	 [Node] Setting-up "_trim_PEs0" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/trim_PEs/mapflow/_trim_PEs0".190406-13:53:39,357 workflow INFO:
# 	 [Node] Setting-up "_trim_PEs1" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/trim_PEs/mapflow/_trim_PEs1".
#
# 190406-13:53:39,364 workflow INFO:
# 	 [Node] Running "_trim_PEs2" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /home/camachocm2/Analysis/SEA/rest_proc/raw/N1011/Humphreys_236989.09.01.21-02-55.WIP_rsEPI-FSP_180mm_MB3R1_HS0.8.01.nii.gz /home/camachocm2/Analysis/SEA/data_QC/Humphreys_236989.09.01.21-02-55.WIP_rsEPI-FSP_180mm_MB3R1_HS0.8.01_roi.nii.gz 0 5
# 190406-13:53:39,370 workflow INFO:
# 	 [Node] Running "_trim_PEs0" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /home/camachocm2/Analysis/SEA/rest_proc/raw/N1011/Humphreys_236989.07.01.20-55-42.WIP_rsEPI-FSA_180mm_MB3R1_HS0.8.01.nii.gz /home/camachocm2/Analysis/SEA/data_QC/Humphreys_236989.07.01.20-55-42.WIP_rsEPI-FSA_180mm_MB3R1_HS0.8.01_roi.nii.gz 0 5190406-13:53:39,370 workflow INFO:
# 	 [Node] Running "_trim_PEs1" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /home/camachocm2/Analysis/SEA/rest_proc/raw/N1011/Humphreys_236989.08.01.20-56-10.WIP_rsEPI-FSP_180mm_MB3R1_HS0.8.01.nii.gz /home/camachocm2/Analysis/SEA/data_QC/Humphreys_236989.08.01.20-56-10.WIP_rsEPI-FSP_180mm_MB3R1_HS0.8.01_roi.nii.gz 0 5
#
# 190406-13:53:40,121 workflow INFO:
# 	 [Node] Finished "_trim_PEs0".
# 190406-13:53:41,260 workflow INFO:
# 	 [Job 7] Completed (_trim_PEs0).
# 190406-13:53:41,264 workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 19.60/20.00, Free processors: 2/4.
#                      Currently running:
#                        * _trim_PEs2
#                        * _trim_PEs1
# 190406-13:53:42,331 workflow INFO:
# 	 [Node] Finished "_trim_PEs1".
# 190406-13:53:42,333 workflow INFO:
# 	 [Node] Finished "_trim_PEs2".
# 190406-13:53:43,262 workflow INFO:
# 	 [Job 8] Completed (_trim_PEs1).
# 190406-13:53:43,265 workflow INFO:
# 	 [Job 9] Completed (_trim_PEs2).
# 190406-13:53:43,268 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 20.00/20.00, Free processors: 4/4.
# 190406-13:53:43,346 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.trim_PEs" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/trim_PEs".
# 190406-13:53:43,357 workflow INFO:
# 	 [Node] Setting-up "_trim_PEs0" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/trim_PEs/mapflow/_trim_PEs0".
# 190406-13:53:43,361 workflow INFO:
# 	 [Node] Cached "_trim_PEs0" - collecting precomputed outputs
# 190406-13:53:43,363 workflow INFO:
# 	 [Node] "_trim_PEs0" found cached.
# 190406-13:53:43,368 workflow INFO:
# 	 [Node] Setting-up "_trim_PEs1" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/trim_PEs/mapflow/_trim_PEs1".
# 190406-13:53:43,373 workflow INFO:
# 	 [Node] Cached "_trim_PEs1" - collecting precomputed outputs
# 190406-13:53:43,376 workflow INFO:
# 	 [Node] "_trim_PEs1" found cached.
# 190406-13:53:43,381 workflow INFO:
# 	 [Node] Setting-up "_trim_PEs2" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/trim_PEs/mapflow/_trim_PEs2".
# 190406-13:53:43,385 workflow INFO:
# 	 [Node] Cached "_trim_PEs2" - collecting precomputed outputs
# 190406-13:53:43,388 workflow INFO:
# 	 [Node] "_trim_PEs2" found cached.
# 190406-13:53:43,392 workflow INFO:
# 	 [Node] Finished "prepreprocflow.trim_PEs".
# 190406-13:53:45,264 workflow INFO:
# 	 [Job 2] Completed (prepreprocflow.trim_PEs).
# 190406-13:53:45,269 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 20.00/20.00, Free processors: 4/4.
# 190406-13:53:45,345 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.sort_pe_list" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/sort_pe_list".
# 190406-13:53:45,352 workflow INFO:
# 	 [Node] Running "sort_pe_list" ("nipype.interfaces.utility.wrappers.Function")
# ['/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/trim_PEs/mapflow/_trim_PEs0/Humphreys_236989.07.01.20-55-42.WIP_rsEPI-FSA_180mm_MB3R1_HS0.8.01_roi.nii.gz', '/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/trim_PEs/mapflow/_trim_PEs1/Humphreys_236989.08.01.20-56-10.WIP_rsEPI-FSP_180mm_MB3R1_HS0.8.01_roi.nii.gz', '/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/trim_PEs/mapflow/_trim_PEs2/Humphreys_236989.09.01.21-02-55.WIP_rsEPI-FSP_180mm_MB3R1_HS0.8.01_roi.nii.gz']
# 190406-13:53:45,360 interface DEBUG:
# 	 in_files_['/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/trim_PEs/mapflow/_trim_PEs0/Humphreys_236989.07.01.20-55-42.WIP_rsEPI-FSA_180mm_MB3R1_HS0.8.01_roi.nii.gz', '/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/trim_PEs/mapflow/_trim_PEs1/Humphreys_236989.08.01.20-56-10.WIP_rsEPI-FSP_180mm_MB3R1_HS0.8.01_roi.nii.gz']
# 190406-13:53:45,363 interface DEBUG:
# 	 merged_file_merged_pes1.nii.gz
# 190406-13:53:46,537 interface DEBUG:
# 	 in_files_['/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/trim_PEs/mapflow/_trim_PEs0/Humphreys_236989.07.01.20-55-42.WIP_rsEPI-FSA_180mm_MB3R1_HS0.8.01_roi.nii.gz', '/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/trim_PEs/mapflow/_trim_PEs2/Humphreys_236989.09.01.21-02-55.WIP_rsEPI-FSP_180mm_MB3R1_HS0.8.01_roi.nii.gz']
# 190406-13:53:46,539 interface DEBUG:
# 	 merged_file_merged_pes1.nii.gz
# 190406-13:53:47,267 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 19.80/20.00, Free processors: 3/4.
#                      Currently running:
#                        * prepreprocflow.sort_pe_list
# 190406-13:53:47,669 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/sort_pe_list/merged_pes1.nii.gz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/sort_pe_list/merged_pes1.nii.gz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/sort_pe_list/_0xe639d18b9cbb19800e36ca3ca34d52f9_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/sort_pe_list/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/sort_pe_list/_node.pklz
# 190406-13:53:47,672 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/sort_pe_list/_report
# 190406-13:53:47,675 workflow DEBUG:
# 	 Removing files:
# 190406-13:53:47,679 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/sort_pe_list/result_sort_pe_list.pklz
# 190406-13:53:47,681 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/sort_pe_list/_report/report.rst"
# 190406-13:53:47,684 workflow DEBUG:
# 	 Aggregate: False
# 190406-13:53:47,687 workflow INFO:
# 	 [Node] Finished "prepreprocflow.sort_pe_list".
# 190406-13:53:49,268 workflow INFO:
# 	 [Job 3] Completed (prepreprocflow.sort_pe_list).
# 190406-13:53:49,273 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 20.00/20.00, Free processors: 4/4.
# 190406-13:53:51,271 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 20.00/20.00, Free processors: 4/4.
# 190406-13:53:51,348 workflow INFO:
# 	 [Node] Setting-up "_topup0" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/topup/mapflow/_topup0".190406-13:53:51,350 workflow INFO:
# 	 [Node] Setting-up "_topup1" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/topup/mapflow/_topup1".
#
# 190406-13:53:51,358 workflow INFO:
# 	 [Node] Running "_topup0" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/home/camachocm2/Analysis/SEA/rest_proc/misc/SEA_rest_encoding.txt --imain=/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/sort_pe_list/merged_pes1.nii.gz --out=merged_pes1_base --iout=merged_pes1_corrected.nii.gz --fout=merged_pes1_field.nii.gz --jacout=jac --logout=merged_pes1_topup.log --rbmout=xfm --dfout=warpfield190406-13:53:51,359 workflow INFO:
# 	 [Node] Running "_topup1" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/home/camachocm2/Analysis/SEA/rest_proc/misc/SEA_rest_encoding.txt --imain=/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/sort_pe_list/merged_pes1.nii.gz --out=merged_pes1_base --iout=merged_pes1_corrected.nii.gz --fout=merged_pes1_field.nii.gz --jacout=jac --logout=merged_pes1_topup.log --rbmout=xfm --dfout=warpfield
#
# 190406-13:53:53,274 workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 19.60/20.00, Free processors: 2/4.
#                      Currently running:
#                        * _topup1
#                        * _topup0
# 190406-14:15:14,458 workflow INFO:
# 	 [Node] Finished "_topup0".
# 190406-14:15:14,578 workflow INFO:
# 	 [Job 10] Completed (_topup0).
# 190406-14:15:14,582 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 19.80/20.00, Free processors: 3/4.
#                      Currently running:
#                        * _topup1
# 190406-14:15:17,881 workflow INFO:
# 	 [Node] Finished "_topup1".
# 190406-14:15:18,582 workflow INFO:
# 	 [Job 11] Completed (_topup1).
# 190406-14:15:18,586 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 20.00/20.00, Free processors: 4/4.
# 190406-14:15:18,683 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.topup" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/topup".
# 190406-14:15:18,696 workflow INFO:
# 	 [Node] Setting-up "_topup0" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/topup/mapflow/_topup0".
# 190406-14:15:18,702 workflow INFO:
# 	 [Node] Cached "_topup0" - collecting precomputed outputs
# 190406-14:15:18,705 workflow INFO:
# 	 [Node] "_topup0" found cached.
# 190406-14:15:18,711 workflow INFO:
# 	 [Node] Setting-up "_topup1" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/topup/mapflow/_topup1".
# 190406-14:15:18,716 workflow INFO:
# 	 [Node] Cached "_topup1" - collecting precomputed outputs
# 190406-14:15:18,720 workflow INFO:
# 	 [Node] "_topup1" found cached.
# 190406-14:15:18,728 workflow INFO:
# 	 [Node] Finished "prepreprocflow.topup".
# 190406-14:15:20,584 workflow INFO:
# 	 [Job 4] Completed (prepreprocflow.topup).
# 190406-14:15:20,589 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 20.00/20.00, Free processors: 4/4.
# 190406-14:15:22,587 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 20.00/20.00, Free processors: 4/4.
# 190406-14:15:22,686 workflow INFO:
# 	 [Node] Setting-up "_apply_topup0" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup0".
# 190406-14:15:22,689 workflow INFO:
# 	 [Node] Setting-up "_apply_topup1" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup1".190406-14:15:22,689 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup0".
#
# 190406-14:15:22,693 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup0/_report/report.rst"
# 190406-14:15:22,698 workflow INFO:
# 	 [Node] Running "_apply_topup1" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/home/camachocm2/Analysis/SEA/rest_proc/misc/SEA_rest_encoding.txt --imain=/home/camachocm2/Analysis/SEA/rest_proc/raw/N1011/Humphreys_236989.09.01.21-02-55.WIP_rsEPI-FSP_180mm_MB3R1_HS0.8.01.nii.gz --inindex=2 --topup=/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup1/merged_pes1_base --method=jac --out=func_unwarped.nii.gz190406-14:15:22,700 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
#
# 190406-14:15:22,704 interface DEBUG:
# 	 encoding_file_/home/camachocm2/Analysis/SEA/rest_proc/misc/SEA_rest_encoding.txt
# 190406-14:15:22,707 interface DEBUG:
# 	 in_files_['/home/camachocm2/Analysis/SEA/rest_proc/raw/N1011/Humphreys_236989.08.01.20-56-10.WIP_rsEPI-FSP_180mm_MB3R1_HS0.8.01.nii.gz']
# 190406-14:15:22,709 interface DEBUG:
# 	 in_index_[2]
# 190406-14:15:22,711 interface DEBUG:
# 	 method_jac
# 190406-14:15:22,714 interface DEBUG:
# 	 out_corrected_func_unwarped.nii.gz
# 190406-14:15:22,716 workflow INFO:
# 	 [Node] Running "_apply_topup0" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/home/camachocm2/Analysis/SEA/rest_proc/misc/SEA_rest_encoding.txt --imain=/home/camachocm2/Analysis/SEA/rest_proc/raw/N1011/Humphreys_236989.08.01.20-56-10.WIP_rsEPI-FSP_180mm_MB3R1_HS0.8.01.nii.gz --inindex=2 --topup=/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup0/merged_pes1_base --method=jac --out=func_unwarped.nii.gz
# 190406-14:15:22,720 interface DEBUG:
# 	 encoding_file_/home/camachocm2/Analysis/SEA/rest_proc/misc/SEA_rest_encoding.txt
# 190406-14:15:22,723 interface DEBUG:
# 	 in_files_['/home/camachocm2/Analysis/SEA/rest_proc/raw/N1011/Humphreys_236989.08.01.20-56-10.WIP_rsEPI-FSP_180mm_MB3R1_HS0.8.01.nii.gz']
# 190406-14:15:22,726 interface DEBUG:
# 	 in_index_[2]
# 190406-14:15:22,729 interface DEBUG:
# 	 method_jac
# 190406-14:15:22,733 interface DEBUG:
# 	 out_corrected_func_unwarped.nii.gz
# 190406-14:15:24,589 workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 19.60/20.00, Free processors: 2/4.
#                      Currently running:
#                        * _apply_topup1
#                        * _apply_topup0
# 190406-14:16:36,432 workflow INFO:
# 	 [Node] Finished "_apply_topup1".
# 190406-14:16:36,661 workflow INFO:
# 	 [Job 13] Completed (_apply_topup1).
# 190406-14:16:36,665 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 19.80/20.00, Free processors: 3/4.
#                      Currently running:
#                        * _apply_topup0
# 190406-14:16:36,848 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup0/func_unwarped.nii.gz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup0/_0x6076095df96f371c4224f635ce51b227_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup0/command.txt;/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup0/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup0/_node.pklz
# 190406-14:16:36,850 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup0/_report
# 190406-14:16:36,853 workflow DEBUG:
# 	 Removing files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup0/merged_pes1_base_fieldcoef.nii.gz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup0/merged_pes1_base_movpar.txt
# 190406-14:16:36,858 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup0/result__apply_topup0.pklz
# 190406-14:16:36,862 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup0/_report/report.rst"
# 190406-14:16:36,865 workflow DEBUG:
# 	 Aggregate: False
# 190406-14:16:36,868 workflow INFO:
# 	 [Node] Finished "_apply_topup0".
# 190406-14:16:38,663 workflow INFO:
# 	 [Job 12] Completed (_apply_topup0).
# 190406-14:16:38,667 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 20.00/20.00, Free processors: 4/4.
# 190406-14:16:38,760 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.apply_topup" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup".
# 190406-14:16:38,770 workflow INFO:
# 	 [Node] Setting-up "_apply_topup0" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup0".
# 190406-14:16:38,775 workflow INFO:
# 	 [Node] Cached "_apply_topup0" - collecting precomputed outputs
# 190406-14:16:38,777 workflow INFO:
# 	 [Node] "_apply_topup0" found cached.
# 190406-14:16:38,781 workflow INFO:
# 	 [Node] Setting-up "_apply_topup1" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/apply_topup/mapflow/_apply_topup1".
# 190406-14:16:38,784 workflow INFO:
# 	 [Node] Cached "_apply_topup1" - collecting precomputed outputs
# 190406-14:16:38,786 workflow INFO:
# 	 [Node] "_apply_topup1" found cached.
# 190406-14:16:38,791 workflow INFO:
# 	 [Node] Finished "prepreprocflow.apply_topup".
# 190406-14:16:40,665 workflow INFO:
# 	 [Job 5] Completed (prepreprocflow.apply_topup).
# 190406-14:16:40,670 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 20.00/20.00, Free processors: 4/4.
# 190406-14:16:40,761 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.datasink" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/datasink".
# 190406-14:16:40,772 workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190406-14:16:40,775 interface INFO:
# 	 sub: /home/camachocm2/Analysis/SEA/rest_proc/preproc/unwarped_funcs/_subject_id_N1011/_apply_topup0/func_unwarped.nii.gz -> /home/camachocm2/Analysis/SEA/rest_proc/preproc/unwarped_funcs/N1011/_apply_topup0/func_unwarped.nii.gz
# 190406-14:16:42,668 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 19.80/20.00, Free processors: 3/4.
#                      Currently running:
#                        * prepreprocflow.datasink
# 190406-14:16:42,869 interface INFO:
# 	 sub: /home/camachocm2/Analysis/SEA/rest_proc/preproc/unwarped_funcs/_subject_id_N1011/_apply_topup1/func_unwarped.nii.gz -> /home/camachocm2/Analysis/SEA/rest_proc/preproc/unwarped_funcs/N1011/_apply_topup1/func_unwarped.nii.gz
# 190406-14:16:44,887 workflow INFO:
# 	 [Node] Finished "prepreprocflow.datasink".
# 190406-14:16:46,671 workflow INFO:
# 	 [Job 6] Completed (prepreprocflow.datasink).
# 190406-14:16:46,676 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 20.00/20.00, Free processors: 4/4.

# %% [markdown]
# ### Basic Preprocessing

# %%
if sequence=='spiral': 
    func_template = {'func': raw_data + '/%s/rest*.nii.gz'}
    select_func = Node(DataGrabber(sort_filelist=True,
                                   template = raw_data + '/%s/rest*.nii.gz',
                                   field_template = func_template,
                                   base_directory=raw_data,
                                   infields=['subject_id'], 
                                   template_args={'func':[['subject_id']]}), 
                       name='select_func')
    #Slice timing correction based on interleaved acquisition using FSL
    slicetime_correct = Node(SliceTimer(interleaved=interleave,
                                        slice_direction=slice_dir,
                                        time_repetition=TR,
                                        out_file='st_func.nii.gz'),
                             name='slicetime_correct')
    
elif sequence=='mux6':
    func_template = {'func': output_dir + '/unwarped_funcs/%s/*/func_unwarped.nii.gz'}
    select_func = Node(DataGrabber(sort_filelist=True,
                                   template = output_dir + '/unwarped_funcs/%s/*/func_unwarped.nii.gz',
                                   field_template = func_template,
                                   base_directory=raw_data,
                                   infields=['subject_id'], 
                                   template_args={'func':[['subject_id']]}), 
                       name='select_func')
    #Slice timing correction 
    slicetime_correct = Node(SliceTimer(time_repetition=TR,
                                        #custom_timings=custom_timings,
                                        interleaved=True,
                                        out_file='st_func.nii.gz'),
                             name='slicetime_correct')

# %%
## struct processing
# reorient to standard
reorientstruct = Node(Reorient2Std(), name='reorientstruct')

# convert files to nifti
reslice_struct = Node(MRIConvert(out_type='niigz',
                                 conform_size=2,
                                 crop_size=(128, 128, 128),
                                ),
                   name='reslice_struct')
# Segment structural scan
segment = Node(FAST(no_bias=True, 
                    segments=True, 
                    number_classes=3), 
               name='segment')

# register BOLD to anat
coregT2 = Node(FLIRT(out_matrix_file='xform.mat'),
           name='coregT2')

# apply transform to func
applyT2xform = Node(FLIRT(apply_xfm=True),
                    name='applyT2xform')

# register anat to template
reg_temp = Node(FLIRT(reference=template_brain, 
                      out_matrix_file='xform.mat',
                      out_file='preproc_anat.nii.gz'),
                name='reg_temp')

# apply transform to func
applyxform = Node(FLIRT(reference=template_brain,
                        apply_xfm=True, 
                        out_file='preproc_func.nii.gz'),
                  name='applyxform')

# %%
def combine_fd(fd_list):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import abspath
    from numpy import asarray, savetxt
    
    motion = open(fd_list[0]).read().splitlines()

    if len(fd_list)>1:
        for file in fd_list[1:]:
            temp = open(file).read().splitlines()
            motion = motion+temp

    motion = asarray(motion).astype(float)
    filename = 'FD_full.txt'
    savetxt(filename,motion)
    combined_fd = abspath(filename)
    return(combined_fd)


def combine_par(par_list):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import abspath
    from numpy import vstack, savetxt, genfromtxt
    
    motion = genfromtxt(par_list[0], dtype=float)
    if len(par_list)>1:
        for file in par_list[1:]:
            temp = genfromtxt(par_list[0], dtype=float)
            motion=vstack((motion,temp))
    
    filename = 'motion.par'
    savetxt(filename, motion, delimiter=' ')
    combined_par = abspath(filename)
    return(combined_par)

# %%
# Data QC nodes
def create_coreg_plot(epi,anat):
    import os
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nilearn import plotting
    
    coreg_filename='coregistration.png'
    display = plotting.plot_anat(epi, display_mode='ortho',
                                 draw_cross=False,
                                 title = 'coregistration to anatomy')
    display.add_edges(anat)
    display.savefig(coreg_filename) 
    display.close()
    coreg_file = os.path.abspath(coreg_filename)
    
    return(coreg_file)

def check_mask_coverage(epi,brainmask):
    from os.path import abspath
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nilearn import plotting
    from nipype.interfaces.nipy.preprocess import Trim
    
    trim = Trim()
    trim.inputs.in_file = epi
    trim.inputs.end_index = 1
    trim.inputs.out_file = 'epi_vol1.nii.gz'
    trim.run()
    epi_vol = abspath('epi_vol1.nii.gz')
    
    maskcheck_filename='maskcheck.png'
    display = plotting.plot_anat(epi_vol, display_mode='ortho',
                                 draw_cross=False,
                                 title = 'brainmask coverage')
    display.add_contours(brainmask,levels=[.5], colors='r')
    display.savefig(maskcheck_filename)
    display.close()
    maskcheck_file = abspath(maskcheck_filename)

    return(maskcheck_file)

make_coreg_img = Node(Function(input_names=['epi','anat'],
                               output_names=['coreg_file'],
                               function=create_coreg_plot), name='make_coreg_img')

make_checkmask_img = Node(
    Function(input_names=['epi','brainmask'],
             output_names=['maskcheck_file'],
             function=check_mask_coverage), name='make_checkmask_img')
make_checkmask_img.inputs.brainmask = template_mask

# %%
## Nodes for func preprocessing
# Reorient to standard space using FSL
reorientfunc = MapNode(Reorient2Std(), name='reorientfunc', iterfield=['in_file'])

# Trim first 4 volumes
trimvols = MapNode(Trim(begin_index=vols_to_trim), name='trimvols', iterfield=['in_file'])

# Motion correction
motion_correct = MapNode(MCFLIRT(save_plots=True), name='motion_correct', iterfield=['in_file'])

# Get frame-wise displacement for each run: in_file; out_file, out_metric_plot, out_metric_values
get_FD = MapNode(MotionOutliers(metric = 'fd',
                                out_metric_values = 'FD.txt',
                                out_metric_plot = 'motionplot.png',
                                threshold=0.001,
                                no_motion_correction=False),
                    name='get_FD', iterfield=['in_file'])

# Merge rest
merge = Node(Merge(dimension='t'), name='merge')

# Merge motion (6 params)
comb_par = Node(Function(input_names=['par_list'],
                         output_names=['combined_par'],
                         function=combine_par), name='comb_par')

# Merge FD
comb_fd = Node(Function(input_names=['fd_list'],
                         output_names=['combined_fd'],
                         function=combine_fd), name='comb_fd')

# Rigid body realignment
realignment = Node(MCFLIRT(), name='realignment')

# unzip the nifti for ART
gunzip = Node(Gunzip(), name='gunzip')

# Artifact detection for scrubbing/motion assessment
art = Node(ArtifactDetect(mask_type='file',
                          parameter_source='FSL',
                          norm_threshold=0.25, #mutually exclusive with rotation and translation thresh
                          zintensity_threshold=2,
                          use_differences=[True, False], 
                          mask_file=template_mask),
           name='art')

# %%
## Preprocessing Workflow

# workflowname.connect([(node1,node2,[('node1output','node2input')]),
#                    (node2,node3,[('node2output','node3input')])
#                    ])

preprocwf = Workflow(name='preprocwf')
preprocwf.connect([(infosource,select_func,[('subject_id','subject_id')]), 
                   (select_func,reorientfunc,[('func','in_file')]),
                   (reorientfunc,trimvols,[('out_file','in_file')]),
                   (trimvols,motion_correct,[('out_file','in_file')]),
                   (trimvols,get_FD,[('out_file','in_file')]),
                   (motion_correct,merge,[('out_file','in_files')]),
                   (merge,realignment,[('merged_file','in_file')]),
                   (realignment,slicetime_correct,[('out_file','in_file')]),
                   (get_FD,comb_fd,[('out_metric_values','fd_list')]),
                   (motion_correct,comb_par,[('par_file','par_list')]),
                   (comb_par,art,[('combined_par','realignment_parameters')]),
                   (gunzip,art,[('out_file','realigned_files')]),
                   
                   (infosource,select_anat,[('subject_id','subject_id')]),
                   (select_anat,reslice_struct,[('struct','in_file')]),
                   (reslice_struct,reorientstruct,[('out_file','in_file')]),
                   (reorientstruct,make_coreg_img,[('out_file','anat')]),
                   
                   (reorientstruct,coregT2,[('out_file','reference')]),
                   (reorientstruct,applyT2xform,[('out_file','reference')]),
                   (reorientstruct,reg_temp,[('out_file','in_file')]),
                   (reg_temp,applyxform,[('out_matrix_file','in_matrix_file')]),
                   (slicetime_correct,coregT2,[('slice_time_corrected_file','in_file')]),
                   (slicetime_correct,applyT2xform,[('slice_time_corrected_file','in_file')]),
                   (coregT2,applyT2xform,[('out_matrix_file','in_matrix_file')]),
                   (applyT2xform, applyxform,[('out_file','in_file')]),
                   (applyxform,gunzip,[('out_file','in_file')]),
                   (reg_temp,segment,[('out_file','in_files')]),
                   (coregT2,make_coreg_img,[('out_file','epi')]),
                   (applyxform,make_checkmask_img,[('out_file','epi')]),
                   (applyxform, datasink, [('out_file','preproc_func')]),
                   (reg_temp, datasink,[('out_file','preproc_anat')]),
                   
                   (comb_fd, datasink, [('combined_fd','FD_out_metric_values')]),
                   (comb_par,datasink,[('combined_par','motion_params')]),
                   (segment,datasink,[('tissue_class_files','tissue_class_files')]),
                   (art,datasink, [('plot_files','art_plot_files')]),
                   (art,datasink, [('outlier_files','vols_to_censor')]),
                   (make_checkmask_img,datasink,[('maskcheck_file','maskcheck_image')]),
                   (make_coreg_img,datasink,[('coreg_file','coreg_image')])                   
                  ])
preprocwf.base_dir = workflow_dir
preprocwf.write_graph(graph2use='flat')
preprocwf.run('MultiProc', plugin_args={'n_procs': proc_cores})
# Out:
# 190406-14:16:49,839 workflow INFO:
# 	 Generated workflow graph: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/graph.png (graph2use=flat, simple_form=True).
# 190406-14:16:49,880 workflow INFO:
# 	 Workflow preprocwf settings: ['check', 'execution', 'logging', 'monitoring']
# 190406-14:16:49,912 workflow INFO:
# 	 Running in parallel.
# 190406-14:16:49,916 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:16:50,28 workflow INFO:
# 	 [Node] Setting-up "preprocwf.selectanat" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/selectanat".190406-14:16:50,28 workflow INFO:
# 	 [Node] Setting-up "preprocwf.select_func" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/select_func".
#
# 190406-14:16:50,40 workflow INFO:
# 	 [Node] Running "selectanat" ("nipype.interfaces.io.SelectFiles")190406-14:16:50,41 workflow INFO:
# 	 [Node] Running "select_func" ("nipype.interfaces.io.DataGrabber")
#
# 190406-14:16:50,52 workflow INFO:
# 	 [Node] Finished "preprocwf.selectanat".190406-14:16:50,53 workflow INFO:
# 	 [Node] Finished "preprocwf.select_func".
#
# 190406-14:16:51,918 workflow INFO:
# 	 [Job 0] Completed (preprocwf.select_func).
# 190406-14:16:51,923 workflow INFO:
# 	 [Job 10] Completed (preprocwf.selectanat).
# 190406-14:16:51,928 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:16:52,45 workflow INFO:
# 	 [Node] Setting-up "preprocwf.reslice_struct" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reslice_struct".
# 190406-14:16:52,58 workflow INFO:
# 	 [Node] Running "reslice_struct" ("nipype.interfaces.freesurfer.preprocess.MRIConvert"), a CommandLine Interface with command:
# mri_convert --conform_size 2.0 --cropsize 128 128 128 --out_type nii --input_volume /home/camachocm2/Analysis/SEA/rest_proc/raw/N1011/skullstripped_anat.nii.gz --output_volume /home/camachocm2/Analysis/SEA/data_QC/skullstripped_anat_out.nii.gz
# 190406-14:16:53,922 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.reslice_struct
# 190406-14:16:54,13 workflow INFO:
# 	 [Node] Setting-up "_reorientfunc1" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reorientfunc/mapflow/_reorientfunc1".190406-14:16:54,13 workflow INFO:
# 	 [Node] Setting-up "_reorientfunc0" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reorientfunc/mapflow/_reorientfunc0".
#
# 190406-14:16:54,21 workflow INFO:
# 	 [Node] Running "_reorientfunc1" ("nipype.interfaces.fsl.utils.Reorient2Std"), a CommandLine Interface with command:
# fslreorient2std /home/camachocm2/Analysis/SEA/rest_proc/preproc/unwarped_funcs/N1011/_apply_topup1/func_unwarped.nii.gz /home/camachocm2/Analysis/SEA/data_QC/func_unwarped_reoriented.nii.gz
# 190406-14:16:54,24 workflow INFO:
# 	 [Node] Running "_reorientfunc0" ("nipype.interfaces.fsl.utils.Reorient2Std"), a CommandLine Interface with command:
# fslreorient2std /home/camachocm2/Analysis/SEA/rest_proc/preproc/unwarped_funcs/N1011/_apply_topup0/func_unwarped.nii.gz /home/camachocm2/Analysis/SEA/data_QC/func_unwarped_reoriented.nii.gz
# 190406-14:16:55,364 workflow INFO:
# 	 [Node] Finished "preprocwf.reslice_struct".
# 190406-14:16:55,921 workflow INFO:
# 	 [Job 11] Completed (preprocwf.reslice_struct).
# 190406-14:16:55,926 workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 56.15/56.55, Free processors: 2/4.
#                      Currently running:
#                        * _reorientfunc1
#                        * _reorientfunc0
# 190406-14:16:56,18 workflow INFO:
# 	 [Node] Setting-up "preprocwf.reorientstruct" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reorientstruct".
# 190406-14:16:56,26 workflow INFO:
# 	 [Node] Running "reorientstruct" ("nipype.interfaces.fsl.utils.Reorient2Std"), a CommandLine Interface with command:
# fslreorient2std /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reslice_struct/skullstripped_anat_out.nii.gz /home/camachocm2/Analysis/SEA/data_QC/skullstripped_anat_out_reoriented.nii.gz
# 190406-14:16:57,521 workflow INFO:
# 	 [Node] Finished "preprocwf.reorientstruct".
# 190406-14:16:57,923 workflow INFO:
# 	 [Job 12] Completed (preprocwf.reorientstruct).
# 190406-14:16:57,929 workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 56.15/56.55, Free processors: 2/4.
#                      Currently running:
#                        * _reorientfunc1
#                        * _reorientfunc0
# 190406-14:16:58,26 workflow INFO:
# 	 [Node] Setting-up "preprocwf.reg_temp" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reg_temp".
# 190406-14:16:58,37 workflow INFO:
# 	 [Node] Running "reg_temp" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reorientstruct/skullstripped_anat_out_reoriented.nii.gz -ref /home/camachocm2/Analysis/SEA/templates/neonate_T2w_template_2mm.nii.gz -out preproc_anat.nii.gz -omat xform.mat
# 190406-14:16:59,528 workflow INFO:
# 	 [Node] Finished "_reorientfunc1".
# 190406-14:16:59,530 workflow INFO:
# 	 [Node] Finished "_reorientfunc0".
# 190406-14:16:59,925 workflow INFO:
# 	 [Job 23] Completed (_reorientfunc0).
# 190406-14:16:59,929 workflow INFO:
# 	 [Job 24] Completed (_reorientfunc1).
# 190406-14:16:59,934 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.reg_temp
# 190406-14:17:00,25 workflow INFO:
# 	 [Node] Setting-up "preprocwf.reorientfunc" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reorientfunc".
# 190406-14:17:00,33 workflow INFO:
# 	 [Node] Setting-up "_reorientfunc0" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reorientfunc/mapflow/_reorientfunc0".
# 190406-14:17:00,36 workflow INFO:
# 	 [Node] Cached "_reorientfunc0" - collecting precomputed outputs
# 190406-14:17:00,38 workflow INFO:
# 	 [Node] "_reorientfunc0" found cached.
# 190406-14:17:00,41 workflow INFO:
# 	 [Node] Setting-up "_reorientfunc1" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reorientfunc/mapflow/_reorientfunc1".
# 190406-14:17:00,45 workflow INFO:
# 	 [Node] Cached "_reorientfunc1" - collecting precomputed outputs
# 190406-14:17:00,46 workflow INFO:
# 	 [Node] "_reorientfunc1" found cached.
# 190406-14:17:00,51 workflow INFO:
# 	 [Node] Finished "preprocwf.reorientfunc".
# 190406-14:17:01,927 workflow INFO:
# 	 [Job 1] Completed (preprocwf.reorientfunc).
# 190406-14:17:01,933 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.reg_temp
# 190406-14:17:03,930 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.reg_temp
# 190406-14:17:04,40 workflow INFO:
# 	 [Node] Setting-up "_trimvols0" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/trimvols/mapflow/_trimvols0".190406-14:17:04,40 workflow INFO:
# 	 [Node] Setting-up "_trimvols1" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/trimvols/mapflow/_trimvols1".
#
# 190406-14:17:04,47 workflow INFO:
# 	 [Node] Running "_trimvols1" ("nipype.interfaces.nipy.preprocess.Trim")190406-14:17:04,48 workflow INFO:
# 	 [Node] Running "_trimvols0" ("nipype.interfaces.nipy.preprocess.Trim")
#
# 190406-14:17:05,933 workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 55.95/56.55, Free processors: 1/4.
#                      Currently running:
#                        * _trimvols1
#                        * _trimvols0
#                        * preprocwf.reg_temp
# 190406-14:17:24,304 workflow INFO:
# 	 [Node] Finished "preprocwf.reg_temp".
# 190406-14:17:25,952 workflow INFO:
# 	 [Job 16] Completed (preprocwf.reg_temp).
# 190406-14:17:25,956 workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 56.15/56.55, Free processors: 2/4.
#                      Currently running:
#                        * _trimvols1
#                        * _trimvols0
# 190406-14:17:26,42 workflow INFO:
# 	 [Node] Setting-up "preprocwf.segment" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/segment".
# 190406-14:17:26,51 workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -N -n 3 -g -S 1 /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/segment/preproc_anat.nii.gz
# 190406-14:17:27,165 workflow INFO:
# 	 [Node] Finished "_trimvols1".
# 190406-14:17:27,397 workflow INFO:
# 	 [Node] Finished "_trimvols0".
# 190406-14:17:27,954 workflow INFO:
# 	 [Job 25] Completed (_trimvols0).
# 190406-14:17:27,956 workflow INFO:
# 	 [Job 26] Completed (_trimvols1).
# 190406-14:17:27,960 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.segment
# 190406-14:17:28,44 workflow INFO:
# 	 [Node] Setting-up "preprocwf.trimvols" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/trimvols".
# 190406-14:17:28,53 workflow INFO:
# 	 [Node] Setting-up "_trimvols0" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/trimvols/mapflow/_trimvols0".
# 190406-14:17:28,58 workflow INFO:
# 	 [Node] Cached "_trimvols0" - collecting precomputed outputs
# 190406-14:17:28,61 workflow INFO:
# 	 [Node] "_trimvols0" found cached.
# 190406-14:17:28,66 workflow INFO:
# 	 [Node] Setting-up "_trimvols1" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/trimvols/mapflow/_trimvols1".
# 190406-14:17:28,70 workflow INFO:
# 	 [Node] Cached "_trimvols1" - collecting precomputed outputs
# 190406-14:17:28,73 workflow INFO:
# 	 [Node] "_trimvols1" found cached.
# 190406-14:17:28,80 workflow INFO:
# 	 [Node] Finished "preprocwf.trimvols".
# 190406-14:17:29,956 workflow INFO:
# 	 [Job 2] Completed (preprocwf.trimvols).
# 190406-14:17:29,961 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.segment
# 190406-14:17:31,959 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.segment
# 190406-14:17:32,50 workflow INFO:
# 	 [Node] Setting-up "_get_FD0" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/get_FD/mapflow/_get_FD0".190406-14:17:32,49 workflow INFO:
# 	 [Node] Setting-up "_motion_correct1" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/motion_correct/mapflow/_motion_correct1".190406-14:17:32,50 workflow INFO:
# 	 [Node] Setting-up "_motion_correct0" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/motion_correct/mapflow/_motion_correct0".
#
#
# 190406-14:17:32,58 workflow INFO:
# 	 [Node] Running "_get_FD0" ("nipype.interfaces.fsl.utils.MotionOutliers"), a CommandLine Interface with command:
# fsl_motion_outliers -i /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/trimvols/mapflow/_trimvols0/func_unwarped_reoriented_trim.nii.gz --fd -o func_unwarped_reoriented_trim_outliers.txt -p motionplot.png -s FD.txt --thresh=0.001190406-14:17:32,59 workflow INFO:
# 	 [Node] Running "_motion_correct1" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/trimvols/mapflow/_trimvols1/func_unwarped_reoriented_trim.nii.gz -out /home/camachocm2/Analysis/SEA/data_QC/func_unwarped_reoriented_trim_mcf.nii.gz -plots190406-14:17:32,59 workflow INFO:
# 	 [Node] Running "_motion_correct0" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/trimvols/mapflow/_trimvols0/func_unwarped_reoriented_trim.nii.gz -out /home/camachocm2/Analysis/SEA/data_QC/func_unwarped_reoriented_trim_mcf.nii.gz -plots
#
#
# 190406-14:17:33,961 workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 55.75/56.55, Free processors: 0/4.
#                      Currently running:
#                        * _get_FD0
#                        * _motion_correct1
#                        * _motion_correct0
#                        * preprocwf.segment
# 190406-14:17:35,191 workflow INFO:
# 	 [Node] Finished "preprocwf.segment".
# 190406-14:17:35,962 workflow INFO:
# 	 [Job 21] Completed (preprocwf.segment).
# 190406-14:17:35,967 workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 55.95/56.55, Free processors: 1/4.
#                      Currently running:
#                        * _get_FD0
#                        * _motion_correct1
#                        * _motion_correct0
# 190406-14:17:36,72 workflow INFO:
# 	 [Node] Setting-up "_get_FD1" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/get_FD/mapflow/_get_FD1".
# 190406-14:17:36,80 workflow INFO:
# 	 [Node] Running "_get_FD1" ("nipype.interfaces.fsl.utils.MotionOutliers"), a CommandLine Interface with command:
# fsl_motion_outliers -i /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/trimvols/mapflow/_trimvols1/func_unwarped_reoriented_trim.nii.gz --fd -o func_unwarped_reoriented_trim_outliers.txt -p motionplot.png -s FD.txt --thresh=0.001
# 190406-14:17:37,966 workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 55.75/56.55, Free processors: 0/4.
#                      Currently running:
#                        * _get_FD1
#                        * _get_FD0
#                        * _motion_correct1
#                        * _motion_correct0
# 190406-14:18:31,211 workflow INFO:
# 	 [Node] Finished "_motion_correct1".
# 190406-14:18:31,848 workflow INFO:
# 	 [Node] Finished "_motion_correct0".
# 190406-14:18:32,21 workflow INFO:
# 	 [Job 27] Completed (_motion_correct0).
# 190406-14:18:32,24 workflow INFO:
# 	 [Job 28] Completed (_motion_correct1).
# 190406-14:18:32,28 workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 56.15/56.55, Free processors: 2/4.
#                      Currently running:
#                        * _get_FD1
#                        * _get_FD0
# 190406-14:18:32,123 workflow INFO:
# 	 [Node] Setting-up "preprocwf.motion_correct" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/motion_correct".
# 190406-14:18:32,684 workflow INFO:
# 	 [Node] Setting-up "_motion_correct0" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/motion_correct/mapflow/_motion_correct0".
# 190406-14:18:32,689 workflow INFO:
# 	 [Node] Cached "_motion_correct0" - collecting precomputed outputs
# 190406-14:18:32,692 workflow INFO:
# 	 [Node] "_motion_correct0" found cached.
# 190406-14:18:32,698 workflow INFO:
# 	 [Node] Setting-up "_motion_correct1" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/motion_correct/mapflow/_motion_correct1".
# 190406-14:18:32,703 workflow INFO:
# 	 [Node] Cached "_motion_correct1" - collecting precomputed outputs
# 190406-14:18:32,706 workflow INFO:
# 	 [Node] "_motion_correct1" found cached.
# 190406-14:18:32,714 workflow INFO:
# 	 [Node] Finished "preprocwf.motion_correct".
# 190406-14:18:34,23 workflow INFO:
# 	 [Job 3] Completed (preprocwf.motion_correct).
# 190406-14:18:34,29 workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 56.15/56.55, Free processors: 2/4.
#                      Currently running:
#                        * _get_FD1
#                        * _get_FD0
# 190406-14:18:34,139 workflow INFO:
# 	 [Node] Setting-up "preprocwf.merge" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/merge".190406-14:18:34,140 workflow INFO:
# 	 [Node] Setting-up "preprocwf.comb_par" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_par".
#
# 190406-14:18:34,148 workflow INFO:
# 	 [Node] Running "comb_par" ("nipype.interfaces.utility.wrappers.Function")190406-14:18:34,147 workflow INFO:
# 	 [Node] Running "merge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t func_unwarped_reoriented_trim_mcf_merged.nii.gz /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/motion_correct/mapflow/_motion_correct0/func_unwarped_reoriented_trim_mcf.nii.gz /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/motion_correct/mapflow/_motion_correct1/func_unwarped_reoriented_trim_mcf.nii.gz
#
# 190406-14:18:34,772 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_par/motion.par;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_par/_0xa139d069b302e4db74f06ffbe3ac2b57_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_par/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_par/_node.pklz
# 190406-14:18:34,776 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_par/_report
# 190406-14:18:34,779 workflow DEBUG:
# 	 Removing files:
# 190406-14:18:34,783 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_par/result_comb_par.pklz
# 190406-14:18:34,786 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_par/_report/report.rst"
# 190406-14:18:34,790 workflow DEBUG:
# 	 Aggregate: False
# 190406-14:18:34,794 workflow INFO:
# 	 [Node] Finished "preprocwf.comb_par".
# 190406-14:18:36,25 workflow INFO:
# 	 [Job 7] Completed (preprocwf.comb_par).
# 190406-14:18:36,30 workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 55.95/56.55, Free processors: 1/4.
#                      Currently running:
#                        * preprocwf.merge
#                        * _get_FD1
#                        * _get_FD0
# 190406-14:19:22,916 workflow INFO:
# 	 [Node] Finished "preprocwf.merge".
# 190406-14:19:24,73 workflow INFO:
# 	 [Job 4] Completed (preprocwf.merge).
# 190406-14:19:24,78 workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 56.15/56.55, Free processors: 2/4.
#                      Currently running:
#                        * _get_FD1
#                        * _get_FD0
# 190406-14:19:24,189 workflow INFO:
# 	 [Node] Setting-up "preprocwf.realignment" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/realignment".
# 190406-14:19:24,193 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/realignment".
# 190406-14:19:24,196 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/realignment/_report/report.rst"
# 190406-14:19:24,202 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190406-14:19:24,205 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/merge/func_unwarped_reoriented_trim_mcf_merged.nii.gz
# 190406-14:19:24,207 interface DEBUG:
# 	 out_file_/home/camachocm2/Analysis/SEA/data_QC/func_unwarped_reoriented_trim_mcf_merged_mcf.nii.gz
# 190406-14:19:24,210 workflow INFO:
# 	 [Node] Running "realignment" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/merge/func_unwarped_reoriented_trim_mcf_merged.nii.gz -out /home/camachocm2/Analysis/SEA/data_QC/func_unwarped_reoriented_trim_mcf_merged_mcf.nii.gz
# 190406-14:19:24,213 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/merge/func_unwarped_reoriented_trim_mcf_merged.nii.gz
# 190406-14:19:24,215 interface DEBUG:
# 	 out_file_/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/realignment/func_unwarped_reoriented_trim_mcf_merged_mcf.nii.gz
# 190406-14:19:26,76 workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 55.95/56.55, Free processors: 1/4.
#                      Currently running:
#                        * preprocwf.realignment
#                        * _get_FD1
#                        * _get_FD0
# 190406-14:19:45,419 workflow INFO:
# 	 [Node] Finished "_get_FD0".
# 190406-14:19:46,95 workflow INFO:
# 	 [Job 29] Completed (_get_FD0).
# 190406-14:19:46,100 workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 56.15/56.55, Free processors: 2/4.
#                      Currently running:
#                        * preprocwf.realignment
#                        * _get_FD1
# 190406-14:19:46,269 workflow INFO:
# 	 [Node] Finished "_get_FD1".
# 190406-14:19:48,97 workflow INFO:
# 	 [Job 30] Completed (_get_FD1).
# 190406-14:19:48,100 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.realignment
# 190406-14:19:48,188 workflow INFO:
# 	 [Node] Setting-up "preprocwf.get_FD" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/get_FD".
# 190406-14:19:48,198 workflow INFO:
# 	 [Node] Setting-up "_get_FD0" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/get_FD/mapflow/_get_FD0".
# 190406-14:19:48,201 workflow INFO:
# 	 [Node] Cached "_get_FD0" - collecting precomputed outputs
# 190406-14:19:48,203 workflow INFO:
# 	 [Node] "_get_FD0" found cached.
# 190406-14:19:48,208 workflow INFO:
# 	 [Node] Setting-up "_get_FD1" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/get_FD/mapflow/_get_FD1".
# 190406-14:19:48,212 workflow INFO:
# 	 [Node] Cached "_get_FD1" - collecting precomputed outputs
# 190406-14:19:48,215 workflow INFO:
# 	 [Node] "_get_FD1" found cached.
# 190406-14:19:48,221 workflow INFO:
# 	 [Node] Finished "preprocwf.get_FD".
# 190406-14:19:50,100 workflow INFO:
# 	 [Job 8] Completed (preprocwf.get_FD).
# 190406-14:19:50,104 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.realignment
# 190406-14:19:50,213 workflow INFO:
# 	 [Node] Setting-up "preprocwf.comb_fd" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_fd".
# 190406-14:19:50,220 workflow INFO:
# 	 [Node] Running "comb_fd" ("nipype.interfaces.utility.wrappers.Function")
# 190406-14:19:50,230 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_fd/FD_full.txt;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_fd/_0x8a11322f0d76b37a5a5e787436d30b5a_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_fd/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_fd/_node.pklz
# 190406-14:19:50,233 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_fd/_report
# 190406-14:19:50,235 workflow DEBUG:
# 	 Removing files:
# 190406-14:19:50,238 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_fd/result_comb_fd.pklz
# 190406-14:19:50,241 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_fd/_report/report.rst"
# 190406-14:19:50,243 workflow DEBUG:
# 	 Aggregate: False
# 190406-14:19:50,247 workflow INFO:
# 	 [Node] Finished "preprocwf.comb_fd".
# 190406-14:19:52,102 workflow INFO:
# 	 [Job 9] Completed (preprocwf.comb_fd).
# 190406-14:19:52,106 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.realignment
# 190406-14:21:23,47 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/realignment/func_unwarped_reoriented_trim_mcf_merged_mcf.nii.gz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/realignment/_0xf415d0d069e329fb0ccab2cc33a91ace_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/realignment/command.txt;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/realignment/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/realignment/_node.pklz
# 190406-14:21:23,50 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/realignment/_report
# 190406-14:21:23,52 workflow DEBUG:
# 	 Removing files:
# 190406-14:21:23,55 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/realignment/result_realignment.pklz
# 190406-14:21:23,57 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/realignment/_report/report.rst"
# 190406-14:21:23,61 workflow DEBUG:
# 	 Aggregate: False
# 190406-14:21:23,64 workflow INFO:
# 	 [Node] Finished "preprocwf.realignment".
# 190406-14:21:24,195 workflow INFO:
# 	 [Job 5] Completed (preprocwf.realignment).
# 190406-14:21:24,201 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:21:24,298 workflow INFO:
# 	 [Node] Setting-up "preprocwf.slicetime_correct" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/slicetime_correct".
# 190406-14:21:24,307 workflow INFO:
# 	 [Node] Running "slicetime_correct" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/realignment/func_unwarped_reoriented_trim_mcf_merged_mcf.nii.gz --odd --out=st_func.nii.gz --repeat=1.410000
# 190406-14:21:26,198 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.slicetime_correct
# 190406-14:23:17,286 workflow INFO:
# 	 [Node] Finished "preprocwf.slicetime_correct".
# 190406-14:23:18,314 workflow INFO:
# 	 [Job 6] Completed (preprocwf.slicetime_correct).
# 190406-14:23:18,319 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:23:18,405 workflow INFO:
# 	 [Node] Setting-up "preprocwf.coregT2" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/coregT2".
# 190406-14:23:18,415 workflow INFO:
# 	 [Node] Running "coregT2" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/slicetime_correct/st_func.nii.gz -ref /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reorientstruct/skullstripped_anat_out_reoriented.nii.gz -out st_func_flirt.nii.gz -omat xform.mat
# 190406-14:23:20,317 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.coregT2
# 190406-14:23:27,183 workflow INFO:
# 	 [Node] Finished "preprocwf.coregT2".
# 190406-14:23:28,324 workflow INFO:
# 	 [Job 13] Completed (preprocwf.coregT2).
# 190406-14:23:28,329 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:23:28,437 workflow INFO:
# 	 [Node] Setting-up "preprocwf.applyT2xform" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/applyT2xform".190406-14:23:28,438 workflow INFO:
# 	 [Node] Setting-up "preprocwf.make_coreg_img" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_coreg_img".
#
# 190406-14:23:28,441 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/applyT2xform".190406-14:23:28,442 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_coreg_img".
#
# 190406-14:23:28,445 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/applyT2xform/_report/report.rst"190406-14:23:28,446 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_coreg_img/_report/report.rst"
#
# 190406-14:23:28,451 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]190406-14:23:28,452 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
#
# 190406-14:23:28,455 workflow INFO:
# 	 [Node] Running "make_coreg_img" ("nipype.interfaces.utility.wrappers.Function")
# 190406-14:23:28,457 interface DEBUG:
# 	 apply_xfm_True
# 190406-14:23:28,460 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/slicetime_correct/st_func.nii.gz
# 190406-14:23:28,462 interface DEBUG:
# 	 in_matrix_file_/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/coregT2/xform.mat
# 190406-14:23:28,465 interface DEBUG:
# 	 out_file_st_func_flirt.nii.gz
# 190406-14:23:28,468 interface DEBUG:
# 	 out_matrix_file_st_func_flirt.mat
# 190406-14:23:28,471 interface DEBUG:
# 	 reference_/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reorientstruct/skullstripped_anat_out_reoriented.nii.gz
# 190406-14:23:28,474 workflow INFO:
# 	 [Node] Running "applyT2xform" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/slicetime_correct/st_func.nii.gz -ref /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reorientstruct/skullstripped_anat_out_reoriented.nii.gz -out st_func_flirt.nii.gz -omat st_func_flirt.mat -applyxfm -init /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/coregT2/xform.mat
# 190406-14:23:28,480 interface DEBUG:
# 	 apply_xfm_True
# 190406-14:23:28,483 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/slicetime_correct/st_func.nii.gz
# 190406-14:23:28,486 interface DEBUG:
# 	 in_matrix_file_/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/coregT2/xform.mat
# 190406-14:23:28,489 interface DEBUG:
# 	 out_file_st_func_flirt.nii.gz
# 190406-14:23:28,492 interface DEBUG:
# 	 out_matrix_file_st_func_flirt.mat
# 190406-14:23:28,494 interface DEBUG:
# 	 reference_/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reorientstruct/skullstripped_anat_out_reoriented.nii.gz
# 190406-14:23:29,765 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_coreg_img/coregistration.png;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_coreg_img/_0xacc2ee41e4e926c6cbeebfa89e371ea1_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_coreg_img/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_coreg_img/_node.pklz
# 190406-14:23:29,768 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_coreg_img/_report
# 190406-14:23:29,771 workflow DEBUG:
# 	 Removing files:
# 190406-14:23:29,775 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_coreg_img/result_make_coreg_img.pklz
# 190406-14:23:29,778 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_coreg_img/_report/report.rst"
# 190406-14:23:29,781 workflow DEBUG:
# 	 Aggregate: False
# 190406-14:23:29,784 workflow INFO:
# 	 [Node] Finished "preprocwf.make_coreg_img".
# 190406-14:23:30,325 workflow INFO:
# 	 [Job 15] Completed (preprocwf.make_coreg_img).
# 190406-14:23:30,330 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.applyT2xform
# 190406-14:26:05,817 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/applyT2xform/st_func_flirt.nii.gz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/applyT2xform/_0x9ea54e055275b6d87cae5197275a6e7c_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/applyT2xform/command.txt;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/applyT2xform/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/applyT2xform/_node.pklz
# 190406-14:26:05,819 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/applyT2xform/_report
# 190406-14:26:05,821 workflow DEBUG:
# 	 Removing files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/applyT2xform/st_func_flirt.mat
# 190406-14:26:05,826 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/applyT2xform/result_applyT2xform.pklz
# 190406-14:26:05,828 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/applyT2xform/_report/report.rst"
# 190406-14:26:05,832 workflow DEBUG:
# 	 Aggregate: False
# 190406-14:26:05,835 workflow INFO:
# 	 [Node] Finished "preprocwf.applyT2xform".
# 190406-14:26:06,484 workflow INFO:
# 	 [Job 14] Completed (preprocwf.applyT2xform).
# 190406-14:26:06,488 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:26:06,575 workflow INFO:
# 	 [Node] Setting-up "preprocwf.applyxform" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/applyxform".
# 190406-14:26:06,586 workflow INFO:
# 	 [Node] Running "applyxform" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/applyT2xform/st_func_flirt.nii.gz -ref /home/camachocm2/Analysis/SEA/templates/neonate_T2w_template_2mm.nii.gz -out preproc_func.nii.gz -omat st_func_flirt_flirt.mat -applyxfm -init /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reg_temp/xform.mat
# 190406-14:26:08,487 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.applyxform
# 190406-14:28:50,699 workflow INFO:
# 	 [Node] Finished "preprocwf.applyxform".
# 190406-14:28:52,654 workflow INFO:
# 	 [Job 17] Completed (preprocwf.applyxform).
# 190406-14:28:52,659 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:28:52,752 workflow INFO:
# 	 [Node] Setting-up "preprocwf.gunzip" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/gunzip".
# 190406-14:28:52,754 workflow INFO:
# 	 [Node] Setting-up "preprocwf.make_checkmask_img" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_checkmask_img".
# 190406-14:28:52,757 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_checkmask_img".
# 190406-14:28:52,759 workflow INFO:
# 	 [Node] Running "gunzip" ("nipype.algorithms.misc.Gunzip")
# 190406-14:28:52,761 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_checkmask_img/_report/report.rst"
# 190406-14:28:52,766 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190406-14:28:52,769 workflow INFO:
# 	 [Node] Running "make_checkmask_img" ("nipype.interfaces.utility.wrappers.Function")
# 190406-14:28:54,657 workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 56.15/56.55, Free processors: 2/4.
#                      Currently running:
#                        * preprocwf.make_checkmask_img
#                        * preprocwf.gunzip
# 190406-14:29:08,983 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_checkmask_img/maskcheck.png;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_checkmask_img/_0xd56dde6070cce22a1b2dd4a277ad10e8_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_checkmask_img/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_checkmask_img/_node.pklz
# 190406-14:29:08,986 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_checkmask_img/_report
# 190406-14:29:08,990 workflow DEBUG:
# 	 Removing files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_checkmask_img/epi_vol1.nii.gz
# 190406-14:29:08,995 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_checkmask_img/result_make_checkmask_img.pklz
# 190406-14:29:08,998 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_checkmask_img/_report/report.rst"
# 190406-14:29:09,2 workflow DEBUG:
# 	 Aggregate: False
# 190406-14:29:09,6 workflow INFO:
# 	 [Node] Finished "preprocwf.make_checkmask_img".
# 190406-14:29:10,673 workflow INFO:
# 	 [Job 20] Completed (preprocwf.make_checkmask_img).
# 190406-14:29:10,678 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.gunzip
# 190406-14:29:10,822 workflow INFO:
# 	 [Node] Finished "preprocwf.gunzip".
# 190406-14:29:12,675 workflow INFO:
# 	 [Job 18] Completed (preprocwf.gunzip).
# 190406-14:29:12,680 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:29:12,772 workflow INFO:
# 	 [Node] Setting-up "preprocwf.art" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art".
# 190406-14:29:12,776 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art".
# 190406-14:29:12,780 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art/_report/report.rst"
# 190406-14:29:12,787 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190406-14:29:12,790 workflow INFO:
# 	 [Node] Running "art" ("nipype.algorithms.rapidart.ArtifactDetect")
# 190406-14:29:14,678 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * preprocwf.art
# 190406-14:29:15,788 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art/art.preproc_func_outliers.txt;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art/plot.preproc_func.png;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art/_0xd2cd3054c62abbab1b7af591ff0fd522_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art/_node.pklz
# 190406-14:29:15,791 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art/_report
# 190406-14:29:15,793 workflow DEBUG:
# 	 Removing files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art/norm.preproc_func.txt;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art/mask.preproc_func.nii;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art/stats.preproc_func.txt;/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art/global_intensity.preproc_func.txt
# 190406-14:29:15,797 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art/result_art.pklz
# 190406-14:29:15,801 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art/_report/report.rst"
# 190406-14:29:15,804 workflow DEBUG:
# 	 Aggregate: False
# 190406-14:29:15,807 workflow INFO:
# 	 [Node] Finished "preprocwf.art".
# 190406-14:29:16,679 workflow INFO:
# 	 [Job 19] Completed (preprocwf.art).
# 190406-14:29:16,683 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:29:16,782 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.datasink".
# 190406-14:29:16,788 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.datasink" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/datasink".
# 190406-14:29:16,792 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.datasink".
# 190406-14:29:16,800 workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190406-14:29:16,805 interface INFO:
# 	 sub: /home/camachocm2/Analysis/SEA/rest_proc/preproc/tissue_class_files/_subject_id_N1011/preproc_anat_seg_0.nii.gz -> /home/camachocm2/Analysis/SEA/rest_proc/preproc/tissue_class_files/N1011/preproc_anat_seg_0.nii.gz
# 190406-14:29:16,808 interface INFO:
# 	 sub: /home/camachocm2/Analysis/SEA/rest_proc/preproc/tissue_class_files/_subject_id_N1011/preproc_anat_seg_1.nii.gz -> /home/camachocm2/Analysis/SEA/rest_proc/preproc/tissue_class_files/N1011/preproc_anat_seg_1.nii.gz
# 190406-14:29:16,811 interface INFO:
# 	 sub: /home/camachocm2/Analysis/SEA/rest_proc/preproc/tissue_class_files/_subject_id_N1011/preproc_anat_seg_2.nii.gz -> /home/camachocm2/Analysis/SEA/rest_proc/preproc/tissue_class_files/N1011/preproc_anat_seg_2.nii.gz
# 190406-14:29:16,814 interface INFO:
# 	 sub: /home/camachocm2/Analysis/SEA/rest_proc/preproc/art_plot_files/_subject_id_N1011/plot.preproc_func.png -> /home/camachocm2/Analysis/SEA/rest_proc/preproc/art_plot_files/N1011/plot.preproc_func.png
# 190406-14:29:16,817 interface INFO:
# 	 sub: /home/camachocm2/Analysis/SEA/rest_proc/preproc/coreg_image/_subject_id_N1011/coregistration.png -> /home/camachocm2/Analysis/SEA/rest_proc/preproc/coreg_image/N1011/coregistration.png
# 190406-14:29:16,820 interface INFO:
# 	 sub: /home/camachocm2/Analysis/SEA/rest_proc/preproc/maskcheck_image/_subject_id_N1011/maskcheck.png -> /home/camachocm2/Analysis/SEA/rest_proc/preproc/maskcheck_image/N1011/maskcheck.png
# 190406-14:29:16,824 interface INFO:
# 	 sub: /home/camachocm2/Analysis/SEA/rest_proc/preproc/motion_params/_subject_id_N1011/motion.par -> /home/camachocm2/Analysis/SEA/rest_proc/preproc/motion_params/N1011/motion.par
# 190406-14:29:16,827 interface INFO:
# 	 sub: /home/camachocm2/Analysis/SEA/rest_proc/preproc/vols_to_censor/_subject_id_N1011/art.preproc_func_outliers.txt -> /home/camachocm2/Analysis/SEA/rest_proc/preproc/vols_to_censor/N1011/art.preproc_func_outliers.txt
# 190406-14:29:16,830 interface INFO:
# 	 sub: /home/camachocm2/Analysis/SEA/rest_proc/preproc/preproc_func/_subject_id_N1011/preproc_func.nii.gz -> /home/camachocm2/Analysis/SEA/rest_proc/preproc/preproc_func/N1011/preproc_func.nii.gz
# 190406-14:29:16,833 interface INFO:
# 	 sub: /home/camachocm2/Analysis/SEA/rest_proc/preproc/FD_out_metric_values/_subject_id_N1011/FD_full.txt -> /home/camachocm2/Analysis/SEA/rest_proc/preproc/FD_out_metric_values/N1011/FD_full.txt
# 190406-14:29:16,835 interface INFO:
# 	 sub: /home/camachocm2/Analysis/SEA/rest_proc/preproc/preproc_anat/_subject_id_N1011/preproc_anat.nii.gz -> /home/camachocm2/Analysis/SEA/rest_proc/preproc/preproc_anat/N1011/preproc_anat.nii.gz
# 190406-14:29:16,841 workflow INFO:
# 	 [Node] Finished "prepreprocflow.datasink".
# 190406-14:29:18,681 workflow INFO:
# 	 [Job 22] Completed (prepreprocflow.datasink).
# 190406-14:29:18,686 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.

# %%
# Resting state preprocessing
# Identity node- select subjects
infosource = Node(IdentityInterface(fields=['subject_id']),
                     name='infosource')
infosource.iterables = ('subject_id', subjects_list)


# Data grabber- select fMRI and sMRI
templates = {'func': output_dir + '/preproc_func/{subject_id}/preproc_func.nii.gz',
             'csf': output_dir + '/tissue_class_files/{subject_id}/preproc_anat_seg_0.nii.gz', 
             'vols_to_censor':output_dir + '/vols_to_censor/{subject_id}/art.preproc_func_outliers.txt', 
             'motion_params':output_dir + '/FD_out_metric_values/{subject_id}/FD_full.txt',
             'wm':template_wm}
selectfiles = Node(SelectFiles(templates), name='selectfiles')

# %%
## Pull motion info for all subjects

motion_df_file = output_dir + '/motion_summary/motionSummary.csv'

if isdir(output_dir + '/motion_summary')==False:
    makedirs(output_dir + '/motion_summary')
    motion_df = DataFrame(columns=['meanFD','maxFD','NumCensoredVols','totalVolumes','secondsNotCensored','lengthsNotCensored_descendingSeconds'])
    motion_df.to_csv(motion_df_file)
    
def summarize_motion(motion_df_file, motion_file, vols_to_censor, TR):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import dirname, basename
    from numpy import asarray, mean, insert, zeros, sort
    from pandas import DataFrame, Series, read_csv
    
    motion_df = read_csv(motion_df_file, index_col=0)
    
    motion = asarray(open(motion_file).read().splitlines()).astype(float)
    censvols = asarray(open(vols_to_censor).read().splitlines()).astype(int)
    sec_not_censored = (len(motion)-len(censvols))*TR
    
    if censvols[0]>0:
        periods_not_censored = insert(censvols,0,0)
    else:
        periods_not_censored = censvols
    
    if periods_not_censored[-1]<len(motion):
        periods_not_censored = insert(periods_not_censored,len(periods_not_censored),len(motion))
    
    lengths = zeros(len(periods_not_censored)-1)
    for a in range(0,len(lengths)):
        lengths[a] = periods_not_censored[a+1] - periods_not_censored[a] - 1
    
    lengths = lengths*TR
    
    # sort lengths in descending order
    lengths = sort(lengths)[::-1]

    fp = dirname(motion_file)
    subject = basename(fp)

    motion_df.loc[subject] = [mean(motion),max(motion),len(censvols),len(motion),sec_not_censored,lengths]
    motion_df.to_csv(motion_df_file)

    return()

# Make a list of tissues for component noise removal
def combine_masks(mask1,mask2):
    from nipype.interfaces.fsl.utils import Merge
    from os.path import abspath
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    vols = []
    vols.append(mask1)
    vols.append(mask2)
    
    return(vols)
    
# Remove all noise (GLM with noise params)
def create_noise_matrix(vols_to_censor,motion_params,comp_noise):
    from numpy import genfromtxt, zeros,concatenate, savetxt
    from os import path

    motion = genfromtxt(motion_params, delimiter=' ', dtype=None, skip_header=0)
    comp_noise = genfromtxt(comp_noise, delimiter='\t', dtype=None, skip_header=1)
    censor_vol_list = genfromtxt(vols_to_censor, delimiter='\t', dtype=None, skip_header=0)

    c = len(censor_vol_list)
    d = len(comp_noise)
    if c > 0:
        scrubbing = zeros((d,c),dtype=int)
        for t in range(0,c):
            scrubbing[censor_vol_list[t]][t] = 1    
        noise_matrix = concatenate([motion[:,None],comp_noise,scrubbing],axis=1)
    else:
        noise_matrix = concatenate((motion[:,None],comp_noise),axis=1)

    noise_file = 'noise_matrix.txt'
    savetxt(noise_file, noise_matrix, delimiter='\t')
    noise_filepath = path.abspath(noise_file)
    
    return(noise_filepath)

def convertafni(in_file):
    from nipype.interfaces.afni.utils import AFNItoNIFTI
    from os import path
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    cvt = AFNItoNIFTI()
    cvt.inputs.in_file = in_file
    cvt.inputs.out_file = 'func_filtered.nii.gz'
    cvt.run()
    
    out_file = path.abspath('func_filtered.nii.gz')
    return(out_file)

# Brightness threshold should be 0.75 * the contrast between the median brain intensity and the background
def brightthresh(func):
    import nibabel as nib
    from numpy import median, where
    
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    func_nifti1 = nib.load(func)
    func_data = func_nifti1.get_data()
    func_data = func_data.astype(float)
    
    brain_values = where(func_data > 0)
    median_thresh = median(brain_values)
    bright_thresh = 0.75 * median_thresh
    
    return(bright_thresh)

# %%
# Denoising
merge_confs = Node(Function(input_names=['mask1','mask2'],
                            output_names=['vols'], 
                            function=combine_masks), 
                   name='merge_confs')

compcor = Node(CompCor(merge_method='none'), 
               name='compcor')

noise_mat = Node(Function(input_names=['vols_to_censor','motion_params','comp_noise'],
                          output_names=['noise_filepath'], 
                          function=create_noise_matrix), 
                 name='noise_mat')

denoise = Node(GLM(out_res_name='denoised_residuals.nii.gz', 
                   out_data_name='denoised_func.nii.gz'), 
               name='denoise')

# band pass filtering- all rates are in Hz (1/TR or samples/second)
bandpass = Node(Bandpass(highpass=highpass_freq,
                         lowpass=lowpass_freq), 
                name='bandpass')

afni_convert = Node(Function(input_names=['in_file'],
                             output_names=['out_file'],
                             function=convertafni), 
                    name='afni_convert')

# Spatial smoothing 
brightthresh_filt = Node(Function(input_names=['func'], 
                                  output_names=['bright_thresh'], 
                                  function=brightthresh), 
                         name='brightthresh_filt')    
    
smooth_filt = Node(SUSAN(fwhm=fwhm), name='smooth_filt')

motion_summary = Node(Function(input_names=['motion_df_file','motion_file','vols_to_censor','TR'], 
                               output_names=[], 
                               function=summarize_motion), 
                      name='motion_summary')
motion_summary.inputs.motion_df_file = motion_df_file
motion_summary.inputs.TR = TR

# %%
# workflowname.connect([(node1,node2,[('node1output','node2input')]),
#                       (node2,node3,[('node2output','node3input')])
#                     ])

rs_procwf = Workflow(name='rs_procwf')
rs_procwf.connect([(infosource,selectfiles,[('subject_id','subject_id')]),
                   (selectfiles,compcor,[('func','realigned_file')]),
                   (selectfiles,merge_confs,[('csf','mask1')]),
                   (selectfiles,merge_confs,[('wm','mask2')]),
                   (merge_confs,compcor,[('vols','mask_files')]),
                   (compcor,noise_mat,[('components_file','comp_noise')]),
                   (selectfiles,noise_mat,[('vols_to_censor','vols_to_censor'),
                                           ('motion_params','motion_params')]),
                   (noise_mat,denoise,[('noise_filepath','design')]),
                   (selectfiles,denoise,[('func','in_file')]),
                   (denoise,bandpass,[('out_data','in_file')]),
                   (bandpass,afni_convert,[('out_file','in_file')]),
                   (afni_convert,brightthresh_filt,[('out_file','func')]),
                   (brightthresh_filt,smooth_filt,[('bright_thresh','brightness_threshold')]),
                   (afni_convert,smooth_filt,[('out_file','in_file')]),  
                   (selectfiles, motion_summary, [('motion_params','motion_file'),
                                                  ('vols_to_censor','vols_to_censor')]),
                   
                   (smooth_filt,datasink,[('smoothed_file','proc_func')])
                   ])

rs_procwf.base_dir = workflow_dir
rs_procwf.write_graph(graph2use='flat')
rs_procwf.run('MultiProc', plugin_args={'n_procs': proc_cores})
# Out:
# 190406-14:29:21,550 workflow INFO:
# 	 Generated workflow graph: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/graph.png (graph2use=flat, simple_form=True).
# 190406-14:29:21,585 workflow INFO:
# 	 Workflow rs_procwf settings: ['check', 'execution', 'logging', 'monitoring']
# 190406-14:29:21,603 workflow INFO:
# 	 Running in parallel.
# 190406-14:29:21,607 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:29:21,715 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.selectfiles" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/selectfiles".
# 190406-14:29:21,728 workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190406-14:29:21,744 workflow INFO:
# 	 [Node] Finished "rs_procwf.selectfiles".
# 190406-14:29:23,610 workflow INFO:
# 	 [Job 0] Completed (rs_procwf.selectfiles).
# 190406-14:29:23,614 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:29:23,718 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.motion_summary" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/motion_summary".190406-14:29:23,719 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.merge_confs" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/merge_confs".
#
# 190406-14:29:23,728 workflow INFO:
# 	 [Node] Running "motion_summary" ("nipype.interfaces.utility.wrappers.Function")
# 190406-14:29:23,731 workflow INFO:
# 	 [Node] Running "merge_confs" ("nipype.interfaces.utility.wrappers.Function")
# 190406-14:29:23,741 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/preproc/tissue_class_files/N1011/preproc_anat_seg_0.nii.gz;/home/camachocm2/Analysis/SEA/templates/neonate_T2w_template_2mm_wm.nii.gz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/merge_confs/_0x812ff4518d0bdafc4f925d4c2badb558_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/merge_confs/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/merge_confs/_node.pklz
# 190406-14:29:23,745 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/merge_confs/_report
# 190406-14:29:23,748 workflow DEBUG:
# 	 Removing files:
# 190406-14:29:23,753 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/merge_confs/result_merge_confs.pklz190406-14:29:23,753 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/motion_summary/_0x62b62bcbba76f38518b47074701da4bd_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/motion_summary/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/motion_summary/_node.pklz
#
# 190406-14:29:23,756 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/motion_summary/_report190406-14:29:23,757 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/merge_confs/_report/report.rst"
#
# 190406-14:29:23,760 workflow DEBUG:
# 	 Removing files:
# 190406-14:29:23,762 workflow DEBUG:
# 	 Aggregate: False190406-14:29:23,764 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/motion_summary/result_motion_summary.pklz
#
# 190406-14:29:23,767 workflow INFO:
# 	 [Node] Finished "rs_procwf.merge_confs".190406-14:29:23,767 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/motion_summary/_report/report.rst"
#
# 190406-14:29:23,771 workflow DEBUG:
# 	 Aggregate: False
# 190406-14:29:23,777 workflow INFO:
# 	 [Node] Finished "rs_procwf.motion_summary".
# 190406-14:29:25,612 workflow INFO:
# 	 [Job 1] Completed (rs_procwf.motion_summary).
# 190406-14:29:25,615 workflow INFO:
# 	 [Job 2] Completed (rs_procwf.merge_confs).
# 190406-14:29:25,620 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:29:25,723 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.compcor" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/compcor".
# 190406-14:29:25,731 workflow INFO:
# 	 [Node] Running "compcor" ("nipype.algorithms.confounds.CompCor")
# 190406-14:29:27,615 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * rs_procwf.compcor
# 190406-14:29:47,897 workflow INFO:
# 	 [Node] Finished "rs_procwf.compcor".
# 190406-14:29:49,635 workflow INFO:
# 	 [Job 3] Completed (rs_procwf.compcor).
# 190406-14:29:49,639 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:29:49,759 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.noise_mat" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/noise_mat".
# 190406-14:29:49,766 workflow INFO:
# 	 [Node] Running "noise_mat" ("nipype.interfaces.utility.wrappers.Function")
# 190406-14:29:49,923 workflow INFO:
# 	 [Node] Finished "rs_procwf.noise_mat".
# 190406-14:29:51,637 workflow INFO:
# 	 [Job 4] Completed (rs_procwf.noise_mat).
# 190406-14:29:51,643 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:29:51,747 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.denoise" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/denoise".
# 190406-14:29:51,751 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/denoise".
# 190406-14:29:51,755 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/denoise/_report/report.rst"
# 190406-14:29:51,761 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190406-14:29:51,765 interface DEBUG:
# 	 design_/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/noise_mat/noise_matrix.txt
# 190406-14:29:51,767 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/SEA/rest_proc/preproc/preproc_func/N1011/preproc_func.nii.gz
# 190406-14:29:51,769 interface DEBUG:
# 	 out_data_name_denoised_func.nii.gz
# 190406-14:29:51,771 interface DEBUG:
# 	 out_file_preproc_func_glm.nii.gz
# 190406-14:29:51,774 interface DEBUG:
# 	 out_res_name_denoised_residuals.nii.gz
# 190406-14:29:51,776 workflow INFO:
# 	 [Node] Running "denoise" ("nipype.interfaces.fsl.model.GLM"), a CommandLine Interface with command:
# fsl_glm -i /home/camachocm2/Analysis/SEA/rest_proc/preproc/preproc_func/N1011/preproc_func.nii.gz -d /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/noise_mat/noise_matrix.txt -o preproc_func_glm.nii.gz --out_data=denoised_func.nii.gz --out_res=denoised_residuals.nii.gz
# 190406-14:29:51,779 interface DEBUG:
# 	 design_/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/noise_mat/noise_matrix.txt
# 190406-14:29:51,782 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/SEA/rest_proc/preproc/preproc_func/N1011/preproc_func.nii.gz
# 190406-14:29:51,784 interface DEBUG:
# 	 out_data_name_denoised_func.nii.gz
# 190406-14:29:51,786 interface DEBUG:
# 	 out_file_preproc_func_glm.nii.gz
# 190406-14:29:51,788 interface DEBUG:
# 	 out_res_name_denoised_residuals.nii.gz
# 190406-14:29:53,641 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * rs_procwf.denoise
# 190406-14:45:04,585 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/denoise/denoised_func.nii.gz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/denoise/_0x68b03d852fb22853e5093bb0cfffe505_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/denoise/command.txt;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/denoise/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/denoise/_node.pklz
# 190406-14:45:04,588 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/denoise/_report
# 190406-14:45:04,590 workflow DEBUG:
# 	 Removing files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/denoise/preproc_func_glm.nii.gz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/denoise/denoised_residuals.nii.gz
# 190406-14:45:04,725 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/denoise/result_denoise.pklz
# 190406-14:45:04,729 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/denoise/_report/report.rst"
# 190406-14:45:04,733 workflow DEBUG:
# 	 Aggregate: False
# 190406-14:45:04,737 workflow INFO:
# 	 [Node] Finished "rs_procwf.denoise".
# 190406-14:45:06,566 workflow INFO:
# 	 [Job 5] Completed (rs_procwf.denoise).
# 190406-14:45:06,571 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:45:06,663 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.bandpass" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass".
# 190406-14:45:06,667 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass".
# 190406-14:45:06,671 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass/_report/report.rst"
# 190406-14:45:06,677 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190406-14:45:06,682 interface DEBUG:
# 	 highpass_0.005
# 190406-14:45:06,685 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass/denoised_func.nii.gz
# 190406-14:45:06,687 interface DEBUG:
# 	 lowpass_0.1
# 190406-14:45:06,689 interface DEBUG:
# 	 out_file_denoised_func_bp
# 190406-14:45:06,692 workflow INFO:
# 	 [Node] Running "bandpass" ("nipype.interfaces.afni.preprocess.Bandpass"), a CommandLine Interface with command:
# 3dBandpass -prefix denoised_func_bp 0.005000 0.100000 /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass/denoised_func.nii.gz
# 190406-14:45:06,698 interface DEBUG:
# 	 highpass_0.005
# 190406-14:45:06,701 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass/denoised_func.nii.gz
# 190406-14:45:06,704 interface DEBUG:
# 	 lowpass_0.1
# 190406-14:45:06,708 interface DEBUG:
# 	 out_file_denoised_func_bp
# 190406-14:45:08,569 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * rs_procwf.bandpass
# 190406-14:46:37,68 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass/denoised_func_bp+orig.BRIK;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass/denoised_func_bp+orig.HEAD;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass/_0x585ab1c51b0e57c60ac26cf5ca3a64c0_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass/command.txt;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass/_node.pklz
# 190406-14:46:37,71 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass/_report
# 190406-14:46:37,73 workflow DEBUG:
# 	 Removing files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass/denoised_func.nii.gz
# 190406-14:46:37,78 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass/result_bandpass.pklz
# 190406-14:46:37,81 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass/_report/report.rst"
# 190406-14:46:37,85 workflow DEBUG:
# 	 Aggregate: False
# 190406-14:46:37,89 workflow INFO:
# 	 [Node] Finished "rs_procwf.bandpass".
# 190406-14:46:38,658 workflow INFO:
# 	 [Job 6] Completed (rs_procwf.bandpass).
# 190406-14:46:38,664 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:46:38,784 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.afni_convert" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/afni_convert".
# 190406-14:46:38,814 workflow INFO:
# 	 [Node] Running "afni_convert" ("nipype.interfaces.utility.wrappers.Function")
# 190406-14:46:38,822 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/bandpass/denoised_func_bp+orig.BRIK
# 190406-14:46:38,825 interface DEBUG:
# 	 out_file_func_filtered.nii.gz
# 190406-14:46:38,920 interface INFO:
# 	 stderr 2019-04-06T14:46:38.920646:++ 3dAFNItoNIFTI: AFNI version=AFNI_18.1.01 (Apr  4 2018) [64-bit]
# 190406-14:46:40,660 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * rs_procwf.afni_convert
# 190406-14:47:22,860 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/afni_convert/func_filtered.nii.gz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/afni_convert/_0xf7c4c8662cdb323d44a3cd24e54d5120_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/afni_convert/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/afni_convert/_node.pklz
# 190406-14:47:22,863 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/afni_convert/_report
# 190406-14:47:22,866 workflow DEBUG:
# 	 Removing files:
# 190406-14:47:22,870 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/afni_convert/result_afni_convert.pklz
# 190406-14:47:22,872 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/afni_convert/_report/report.rst"
# 190406-14:47:22,875 workflow DEBUG:
# 	 Aggregate: False
# 190406-14:47:22,878 workflow INFO:
# 	 [Node] Finished "rs_procwf.afni_convert".
# 190406-14:47:24,703 workflow INFO:
# 	 [Job 7] Completed (rs_procwf.afni_convert).
# 190406-14:47:24,708 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:47:24,791 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.brightthresh_filt" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/brightthresh_filt".
# 190406-14:47:24,798 workflow INFO:
# 	 [Node] Running "brightthresh_filt" ("nipype.interfaces.utility.wrappers.Function")
# 190406-14:47:26,707 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * rs_procwf.brightthresh_filt
# 190406-14:48:17,548 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/brightthresh_filt/_0xdba3be5f0f82dced3b2564caab158bb2_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/brightthresh_filt/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/brightthresh_filt/_node.pklz
# 190406-14:48:17,552 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/brightthresh_filt/_report
# 190406-14:48:17,555 workflow DEBUG:
# 	 Removing files:
# 190406-14:48:17,561 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/brightthresh_filt/result_brightthresh_filt.pklz
# 190406-14:48:17,564 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/brightthresh_filt/_report/report.rst"
# 190406-14:48:17,568 workflow DEBUG:
# 	 Aggregate: False
# 190406-14:48:17,572 workflow INFO:
# 	 [Node] Finished "rs_procwf.brightthresh_filt".
# 190406-14:48:18,758 workflow INFO:
# 	 [Job 8] Completed (rs_procwf.brightthresh_filt).
# 190406-14:48:18,762 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:48:18,851 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.smooth_filt" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt".
# 190406-14:48:18,855 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt".
# 190406-14:48:18,858 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt/_report/report.rst"
# 190406-14:48:18,862 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190406-14:48:18,865 interface DEBUG:
# 	 brightness_threshold_48.75
# 190406-14:48:18,868 interface DEBUG:
# 	 dimension_3
# 190406-14:48:18,870 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/afni_convert/func_filtered.nii.gz
# 190406-14:48:18,873 interface DEBUG:
# 	 out_file_/home/camachocm2/Analysis/SEA/data_QC/func_filtered_smooth.nii.gz
# 190406-14:48:18,876 interface DEBUG:
# 	 use_median_1
# 190406-14:48:18,879 workflow INFO:
# 	 [Node] Running "smooth_filt" ("nipype.interfaces.fsl.preprocess.SUSAN"), a CommandLine Interface with command:
# susan /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/afni_convert/func_filtered.nii.gz 48.7500000000 1.6986436006 3 1 0 /home/camachocm2/Analysis/SEA/data_QC/func_filtered_smooth.nii.gz
# 190406-14:48:18,883 interface DEBUG:
# 	 brightness_threshold_48.75
# 190406-14:48:18,886 interface DEBUG:
# 	 dimension_3
# 190406-14:48:18,889 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/afni_convert/func_filtered.nii.gz
# 190406-14:48:18,891 interface DEBUG:
# 	 out_file_/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt/func_filtered_smooth.nii.gz
# 190406-14:48:18,894 interface DEBUG:
# 	 use_median_1
# 190406-14:48:20,761 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 56.35/56.55, Free processors: 3/4.
#                      Currently running:
#                        * rs_procwf.smooth_filt
# 190406-14:59:27,730 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt/func_filtered_smooth.nii.gz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt/_0xc7a4adde041996e41c98df30fe2a07fa_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt/command.txt;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt/_node.pklz
# 190406-14:59:27,732 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt/_report
# 190406-14:59:27,735 workflow DEBUG:
# 	 Removing files:
# 190406-14:59:27,739 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt/result_smooth_filt.pklz
# 190406-14:59:27,741 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt/_report/report.rst"
# 190406-14:59:27,744 workflow DEBUG:
# 	 Aggregate: False
# 190406-14:59:27,746 workflow INFO:
# 	 [Node] Finished "rs_procwf.smooth_filt".
# 190406-14:59:29,450 workflow INFO:
# 	 [Job 9] Completed (rs_procwf.smooth_filt).
# 190406-14:59:29,454 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
# 190406-14:59:29,542 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.datasink".
# 190406-14:59:29,550 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.datasink" in "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/datasink".
# 190406-14:59:29,552 workflow DEBUG:
# 	 [Node] Hashes: [('_outputs', [('proc_func', ('/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt/func_filtered_smooth.nii.gz', '0b04388a3e9780f86f7d3e8b5cf6fb3c'))]), ('base_directory', '/home/camachocm2/Analysis/SEA/rest_proc/preproc'), ('container', '/home/camachocm2/Analysis/SEA/rest_proc/preproc'), ('parameterization', True), ('remove_dest_dir', False), ('substitutions', [('_subject_id_', '')])], 922084bdad15826df61c8e57730462c4, /home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/datasink/_0x922084bdad15826df61c8e57730462c4.json, ['/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/datasink/_0x5c3fabbfcbb63d9005acec6501670d4d.json']
# 190406-14:59:29,555 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.datasink".
# 190406-14:59:29,558 workflow DEBUG:
# 	 [Node] Old/new hashes = 5c3fabbfcbb63d9005acec6501670d4d/922084bdad15826df61c8e57730462c4
# 190406-14:59:29,562 workflow DEBUG:
# 	           Some dictionary entries had differing values:
#             * substitutions: [('_subject_id_', '')] != [['_subject_id_', '']]
#             * _outputs: [('proc_func', ('/home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt/func_filtered_smooth.nii.gz', '0b04388a3e9780f86f7d3e8b5cf6fb3c'))] != [['FD_out_metric_values', ['/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_fd/FD_full.txt', 'e1412c989648f73004625b7e7b8b9762']], ['art_plot_files', ['/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art/plot.preproc_func.png', 'a127e1bc67b12a34ae2fec1c0ebb3e22']], ['coreg_image', ['/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_coreg_img/coregistration.png', 'd697fb18f64808bfc669dccb0151b094']], ['maskcheck_image', ['/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/make_checkmask_img/maskcheck.png', 'cb75c9ccc2c50a0ad2203ab2b23fed6b']], ['motion_params', ['/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/comb_par/motion.par', 'b5b7c4d547ef3d1de57f3fb56750e32f']], ['preproc_anat', ['/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/reg_temp/preproc_anat.nii.gz', '2d450c335f2255f7874ee5e900ef0cee']], ['preproc_func', ['/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/applyxform/preproc_func.nii.gz', '48c18f5ccb9d0fcf4f07627ce2eb3a75']], ['tissue_class_files', [['/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/segment/preproc_anat_seg_0.nii.gz', '1d4fecc4afc2ea9457d1bea799581205'], ['/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/segment/preproc_anat_seg_1.nii.gz', '573c5db8dc74141af56f4c0338e1362e'], ['/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/segment/preproc_anat_seg_2.nii.gz', '6c4aa216e45d49c5f3b9ed65f0c0b516']]], ['vols_to_censor', ['/home/camachocm2/Analysis/SEA/rest_proc/workflows/preprocwf/_subject_id_N1011/art/art.preproc_func_outliers.txt', 'e0311e2450d49a8780909858c3326305']]]
# 190406-14:59:29,566 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/datasink/_report/report.rst"
# 190406-14:59:29,575 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190406-14:59:29,579 workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190406-14:59:29,584 interface DEBUG:
# 	 key: proc_func files: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt/func_filtered_smooth.nii.gz
# 190406-14:59:29,587 interface DEBUG:
# 	 sub.str: /home/camachocm2/Analysis/SEA/rest_proc/preproc/proc_func/_subject_id_N1011/func_filtered_smooth.nii.gz -> /home/camachocm2/Analysis/SEA/rest_proc/preproc/proc_func/N1011/func_filtered_smooth.nii.gz using '_subject_id_' -> ''
# 190406-14:59:29,589 interface INFO:
# 	 sub: /home/camachocm2/Analysis/SEA/rest_proc/preproc/proc_func/_subject_id_N1011/func_filtered_smooth.nii.gz -> /home/camachocm2/Analysis/SEA/rest_proc/preproc/proc_func/N1011/func_filtered_smooth.nii.gz
# 190406-14:59:29,590 interface DEBUG:
# 	 copyfile: /home/camachocm2/Analysis/SEA/rest_proc/workflows/rs_procwf/_subject_id_N1011/smooth_filt/func_filtered_smooth.nii.gz /home/camachocm2/Analysis/SEA/rest_proc/preproc/proc_func/N1011/func_filtered_smooth.nii.gz
# 190406-14:59:29,593 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/SEA/rest_proc/preproc/proc_func/N1011/func_filtered_smooth.nii.gz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/datasink/_0x922084bdad15826df61c8e57730462c4_unfinished.json;/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/datasink/_inputs.pklz;/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/datasink/_node.pklz
# 190406-14:59:29,595 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/datasink/_report
# 190406-14:59:29,597 workflow DEBUG:
# 	 Removing files:
# 190406-14:59:29,600 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/datasink/result_datasink.pklz
# 190406-14:59:29,602 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/SEA/rest_proc/workflows/prepreprocflow/_subject_id_N1011/datasink/_report/report.rst"
# 190406-14:59:29,604 workflow DEBUG:
# 	 Aggregate: False
# 190406-14:59:29,606 workflow INFO:
# 	 [Node] Finished "prepreprocflow.datasink".
# 190406-14:59:31,452 workflow INFO:
# 	 [Job 10] Completed (prepreprocflow.datasink).
# 190406-14:59:31,456 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 4/4.
